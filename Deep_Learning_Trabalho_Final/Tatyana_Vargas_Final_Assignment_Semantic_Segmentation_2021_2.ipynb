# %% [markdown]
# # **Final Assignment - Semantic Segmentation**
#
# Objective: Implement a U-Net Network for Semantic Segmentation
#
# Dataset: ISPRS 2D Semantic Labeling Challenge (Vaihingen)
#
# <figure>
# <center>
# <img src= 'https://drive.google.com/uc?export=view&id=19wmyEXtnTV8gMOn02FPeJ8JcVSKVOycH'/>
# </figure>
#
# In the code below the network was trained only with image Train1.
#
# In the assignment you should use both Train1 and Train2 images to train.
#
# Notice that you will have to adapt the so that the network will take as imput an image concatenated with its DSM.

# %% [markdown]
# # **1. Import libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
from osgeo import ogr, gdal
import cv2

from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Activation, Dense, Flatten, Dropout, concatenate, Conv2D, MaxPool2D, UpSampling2D, Conv2DTranspose, BatchNormalization, MaxPool3D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # **2. Defining root folder**

# %%
# root_path will be used to store trained models

from google.colab import drive
# mount your Google Drive
drive.mount('/content/drive', force_remount=True)

# adjust the path to the location where the models will be written / read
root_path = '/content/drive/My Drive/Colab Notebooks/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **3. Loading the data**

# %%
# Downloading the dataset and unpacking it.
# 6 files: Test_Image.tif, Test_DSM.tif, Test_Reference.tif, Train1_Image.tif, Train1_DSM.tif, Train1_Reference.tif, Train2_Image.tif, Train2_DSM.tif, Train2_Reference.tif

# !wget https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part1.rar
# !wget https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part2.rar
# !wget https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part3.rar
# !unrar e Images_Semantic_Segmentatio_Assignment.part1.rar
# Out:
# --2022-02-12 01:45:12--  https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part1.rar
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part1.rar [following]
# --2022-02-12 01:45:12--  https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part1.rar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25165824 (24M) [application/octet-stream]
# Saving to: ‘Images_Semantic_Segmentatio_Assignment.part1.rar’
#
# Images_Semantic_Seg 100%[===================>]  24.00M  --.-KB/s    in 0.1s
#
# 2022-02-12 01:45:12 (239 MB/s) - ‘Images_Semantic_Segmentatio_Assignment.part1.rar’ saved [25165824/25165824]
#
# --2022-02-12 01:45:12--  https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part2.rar
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part2.rar [following]
# --2022-02-12 01:45:13--  https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part2.rar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25165824 (24M) [application/octet-stream]
# Saving to: ‘Images_Semantic_Segmentatio_Assignment.part2.rar’
#
# Images_Semantic_Seg 100%[===================>]  24.00M  --.-KB/s    in 0.1s
#
# 2022-02-12 01:45:13 (247 MB/s) - ‘Images_Semantic_Segmentatio_Assignment.part2.rar’ saved [25165824/25165824]
#
# --2022-02-12 01:45:13--  https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part3.rar
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part3.rar [following]
# --2022-02-12 01:45:14--  https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part3.rar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9414015 (9.0M) [application/octet-stream]
# Saving to: ‘Images_Semantic_Segmentatio_Assignment.part3.rar’
#
# Images_Semantic_Seg 100%[===================>]   8.98M  --.-KB/s    in 0.06s
#
# 2022-02-12 01:45:14 (138 MB/s) - ‘Images_Semantic_Segmentatio_Assignment.part3.rar’ saved [9414015/9414015]
#
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Images_Semantic_Segmentatio_Assignment.part1.rar
#
#   OK
#  42%
#
# Extracting from Images_Semantic_Segmentatio_Assignment.part2.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#  84%
#
# Extracting from Images_Semantic_Segmentatio_Assignment.part3.rar
#
#   OK
#   OK
#   OK
# All OK

# %%
# Listing the contents of the virtual machine.
# !ls -l
# Out:
# total 226224
# drwx------ 5 root root     4096 Feb 12 01:45 drive
# -rw-r--r-- 1 root root 25165824 Feb 12 01:45 Images_Semantic_Segmentatio_Assignment.part1.rar
# -rw-r--r-- 1 root root 25165824 Feb 12 01:45 Images_Semantic_Segmentatio_Assignment.part2.rar
# -rw-r--r-- 1 root root  9414015 Feb 12 01:45 Images_Semantic_Segmentatio_Assignment.part3.rar
# drwxr-xr-x 1 root root     4096 Feb  1 14:32 sample_data
# -rw-r--r-- 1 root root 28852100 Aug 19  2014 Test_DSM.tif
# -rw-r--r-- 1 root root 21789756 Nov  1  2013 Test_Image.tif
# -rw-r--r-- 1 root root 22326104 Apr 28  2014 Test_Reference.tif
# -rw-r--r-- 1 root root 19707152 Aug 19  2014 Train1_DSM.tif
# -rw-r--r-- 1 root root 14870332 Nov  1  2013 Train1_Image.tif
# -rw-r--r-- 1 root root 15259952 Apr 28  2014 Train1_Reference.tif
# -rw-r--r-- 1 root root 19398356 Aug 19  2014 Train2_DSM.tif
# -rw-r--r-- 1 root root 14643100 Nov  1  2013 Train2_Image.tif
# -rw-r--r-- 1 root root 15036852 Apr 28  2014 Train2_Reference.tif

# %%
# Functions

def load_tiff_image(image):
  print (image)
  gdal_header = gdal.Open(image)
  img_gdal = gdal_header.ReadAsArray()
  img = np.transpose(img_gdal, (1,2,0))
  return img

def normalization(image):
  image_reshaped = image.reshape((image.shape[0]*image.shape[1]),image.shape[2])
  scaler = MinMaxScaler(feature_range=(0,1))
  scaler = scaler.fit(image_reshaped)
  image_normalized_ = scaler.fit_transform(image_reshaped)
  image_normalized = image_normalized_.reshape(image.shape[0],image.shape[1],image.shape[2])
  return image_normalized

#função para DSM: (monocromática)

def load_dsm_image(image):
  print (image)
  gdal_header = gdal.Open(image)
  img_gdal = gdal_header.ReadAsArray()
  return img_gdal


def normalization_dsm(image):
  #load dsm_tif
  print(image)
  gdal_header = gdal.Open(image)
  dsm_gdal = gdal_header.ReadAsArray()
  #normalize loaded dsm_tif
  data = dsm_gdal
  dsm_normalized = (data - np.min(data)) / (np.max(data) - np.min(data))
  return dsm_normalized

# %%
# Loading and normalizing images

#########TRAIN1 Loading

reference_train = load_tiff_image('Train1_Reference.tif')
print(reference_train.shape)
image_train = load_tiff_image('Train1_Image.tif')
# Image DSM
dsm_train = load_dsm_image('Train1_DSM.tif')
print(dsm_train.shape)
#Concatenando imagem com dsm (deve ser comentado caso não seja utilizado)
train_dsm1 = np.array(np.concatenate([image_train,np.expand_dims(dsm_train,axis = 2)],axis = 2))
# Normalizes training image (pixel values from 0 to 1)
##image_train = normalization(image_train)
##print(image_train.shape)
# Normalizes training image with dsm
train_dsm1 = normalization(train_dsm1)
print(train_dsm1.shape)



############TRAIN2 Loading

#reference_train2 = load_tiff_image('Train2_Reference.tif')
#print(reference_train2.shape)
#image_train2 = load_tiff_image('Train2_Image.tif')
# Image DSM
#dsm_train2 = load_dsm_image('Train2_DSM.tif')
#print(dsm_train2.shape)
#Concatenando imagem com dsm (deve ser comentado caso não seja utilizado)
#train_dsm2 = np.array(np.concatenate([image_train2,np.expand_dims(dsm_train2,axis = 2)],axis = 2))
# Normalizes training image (pixel values from 0 to 1)
#image_train2 = normalization(image_train2)
#print(image_train2.shape)
# Normalizes training image with dsm
#train_dsm2 = normalization(train_dsm2)
#print(train_dsm2.shape)

#############TEST Loading

reference_test = load_tiff_image('Test_Reference.tif')
print(reference_test.shape)
image_test = load_tiff_image('Test_Image.tif')
# Image DSM
dsm_test = load_dsm_image('Test_DSM.tif')
print(dsm_test.shape)
#Concatenando imagem com dsm (deve ser comentado caso não seja utilizado)
test_dsm = np.array(np.concatenate([image_test,np.expand_dims(dsm_test,axis = 2)],axis = 2))
# Normalizes testing image (pixel values from 0 to 1)
#image_test = normalization(image_test)
#print(image_test.shape)
# Normalizes training image with dsm
test_dsm = normalization(test_dsm)
print(test_dsm.shape)
# Out:
# Train1_Reference.tif
# (2565, 1919, 3)
# Train1_Image.tif
# Train1_DSM.tif
# (2565, 1919)
# (2565, 1919, 4)
# Test_Reference.tif
# (2558, 2818, 3)
# Test_Image.tif
# Test_DSM.tif
# (2558, 2818)
# (2558, 2818, 4)

# %% [markdown]
# # **4. Creating labeled images from references**

# %%
# Defining number of classes and class indices in relation to reference images (RGB)

num_classes = 6
color2label = {
    (255, 255, 255) : 0,  # Impervious surfaces
    (0,   255, 255) : 1,  # Low vegetation
    (0,     0, 255) : 2,  # Building
    (0,   255,   0) : 3,  # Tree
    (255, 255,   0) : 4   # Car
}

def create_label_image(rgb_image):
  W = np.power(256, [[0],[1],[2]])
  img_index = rgb_image.dot(W).squeeze(-1)
  values = np.unique(img_index)
  label_image = np.zeros(img_index.shape)
  for i, c in enumerate(values):
    try:
      label_image[img_index==c] = color2label[tuple(rgb_image[img_index==c][0])]
    except:
      pass
  return label_image

# %%
# Tranforming regerence RGB images into label images

#train1
labels_train = create_label_image(reference_train)
print(labels_train.shape)

#train2
#labels_train2 = create_label_image(reference_train2)
#print(labels_train2.shape)

#test
labels_test = create_label_image(reference_test)
print(labels_test.shape)
# Out:
# (2565, 1919)
# (2558, 2818)

# %%
# Inspecting label images (train and test)

print('\nPlotting images...')
#train1
fig1, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(14, 10))
ax1.imshow( reference_train )
ax1.set_title('Reference RGB (train1)', fontsize=20)
ax1.axis('off')
ax2.imshow( labels_train, cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference Labels (train1)', fontsize=20)
ax2.axis('off')

#train2 (só precisa aparecer quando trabalhamos com a train1 + train2)
#fig3, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(14, 10))
#ax1.imshow( reference_train2 )
#ax1.set_title('Reference RGB (train2)', fontsize=20)
#ax1.axis('off')
#ax2.imshow( labels_train2, cmap='gray', vmin=0, vmax=num_classes )
#ax2.set_title('Reference Labels (train2)', fontsize=20)
#ax2.axis('off')

#test
fig2, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(14, 10))
ax1.imshow( reference_test )
ax1.set_title('Reference RGB (test)', fontsize=20)
ax1.axis('off')
ax2.imshow( labels_test, cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference Labels (test)', fontsize=20)
ax2.axis('off')
# Out:
# Plotting images...
# (-0.5, 2817.5, 2557.5, -0.5)

# %% [markdown]
# # **5. Extracting image patches for training**

# %%
# Constants and functions

# patch_size defines the measures (spatial dimensions) of the patch.
# Working with square patches (H = W). Therefore, a scalar variable is enough.
patch_size = 256

# patch_stride determine the position of the next patch.
# A patch_stride smaller than the spatial dimension of the patch determines an overlapping.
# 25% ​​overlap between patches.
patch_stride = patch_size - (patch_size // 4)

# channels of the image/patches to be segmented
image_channels = 3
#a linha de código acima deve ser comentada quando trabalhando com dsm

# shape of the input to the network (training)
input_shape = (patch_size, patch_size, image_channels)

# Function: extract_patches
# -------------------------
# Extract patches from the original and reference image
#
# Input parameters:
#   image      = array containing the original image (h,w,c)
#   reference  = array containing the reference image (h,w,c)
#   patch_size = patch size (scalar). The shape of the patch is square.
#   stride     = displacement to be applied.
#   border_patches = include patches overlaping image borders
#
# Returns:
#   A, B = List containing the patches for the input image (A) and respective reference (B).
#
def extract_patches(image, reference, patch_size, stride, border_patches=False):
    print("Image dimensions:", image.shape)
    print("Reference dimensions:", reference.shape)

    patch_img = []
    patch_ref = []

    h = image.shape[0] // stride
    w = image.shape[1] // stride

    for m in range(0, h):
        for n in range(0, w):
            #print('M %d, N %d, start %d finish %d , start %d finish %d' % (m, n, m*stride , m*stride+patch_size, n*stride, n*stride+patch_size) )
            if ( (m*stride+patch_size <= image.shape[0]) and (n*stride+patch_size <= image.shape[1]) ):
                patch_img.append( image[m*stride:m*stride+patch_size,n*stride:n*stride+patch_size,:] )
                patch_ref.append( reference[m*stride:m*stride+patch_size,n*stride:n*stride+patch_size] )
            elif border_patches:
                border_patch_img = np.zeros((patch_size,patch_size,image_channels))
                border_patch_ref = np.zeros((patch_size,patch_size))
                if (m*stride+patch_size > image.shape[0]):
                  border_mmax = patch_size-(m*stride+patch_size-image.shape[0])
                else:
                  border_mmax = patch_size-1
                if (n*stride+patch_size > image.shape[1]):
                  border_nmax = patch_size-(n*stride+patch_size-image.shape[1])
                else:
                  border_nmax = patch_size-1

                border_patch_img[0:border_mmax,0:border_nmax,:] = image[m*stride:m*stride+border_mmax,n*stride:n*stride+border_nmax,:]
                border_patch_ref[0:border_mmax,0:border_nmax] = reference[m*stride:m*stride+border_mmax,n*stride:n*stride+border_nmax]
                patch_img.append( border_patch_img )
                patch_ref.append( border_patch_ref )

    return np.array(patch_img), np.array(patch_ref)

# %% [markdown]
# A célula abaixo deve ser utilizada somente para o treinamento sem DSM.

# %%
# Extracting training patches for train1
x_patches, y_patches = extract_patches(image_train, labels_train, patch_size, patch_stride)

# Transform y_patches, shape (N, H, W) into shape (N, H, W, C). Necessary for data agumentation.
y_patches = np.expand_dims(y_patches, 3)

print( "Number of patches: %d %s " % ( x_patches.shape[0], x_patches.shape[1:] ) )
print( "Number of labeled references: %d %s " % ( y_patches.shape[0], y_patches.shape[1:] ) )

# Extracting training patches of train2
x_patches2, y_patches2 = extract_patches(image_train2, labels_train2, patch_size, patch_stride)

# Transform y_patches, shape (N, H, W) into shape (N, H, W, C). Necessary for data agumentation.
y_patches2 = np.expand_dims(y_patches2, 3)

print( "Number of patches: %d %s " % ( x_patches2.shape[0], x_patches2.shape[1:] ) )
print( "Number of labeled references: %d %s " % ( y_patches2.shape[0], y_patches2.shape[1:] ) )
# Out:
# Image dimensions: (2565, 1919, 3)
# Reference dimensions: (2565, 1919)
# Number of patches: 117 (256, 256, 3)
# Number of labeled references: 117 (256, 256, 1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-d6366388c10e> in <module>()
#       9
#      10 # Extracting training patches of train2
# ---> 11 x_patches2, y_patches2 = extract_patches(image_train2, labels_train2, patch_size, patch_stride)
#      12
#      13 # Transform y_patches, shape (N, H, W) into shape (N, H, W, C). Necessary for data agumentation.
#
# NameError: name 'image_train2' is not defined

# %%
# Inspecting an arbitrary image patch

image_index = 20

print('\nPlotting images...')
fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(14, 10))

ax1.imshow( x_patches[image_index] )
ax1.set_title('Patch', fontsize=20)
ax1.axis('off')

ax2.imshow( y_patches[image_index, :, :, 0], cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Labeled reference', fontsize=20)
ax2.axis('off')
# Out:
# Plotting images...
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# # **6. Separating training and validation patches**

# %%
# Defining the percentage of the training set to be used as validation
valid_percent = 0.2

# Calculating the boundary (index) between training set and validation.
# The premise is always that X and Y have the same number of elements.
limit = len(x_patches) - int (len(x_patches)*valid_percent )

# Building a list of indexes from 0 to N, where N corresponds to the number of images (patches).
indexes = [i for i in range(x_patches.shape[0])]

# Generating randomness in the list
import random
random.shuffle(indexes)

# Indexes of the images that will be used for training
indexes_for_train = indexes[:limit]
# ndexes of the images that will be used for validation
indexes_for_valid = indexes[limit:]

# Training set
x_train = x_patches[indexes_for_train]
y_train = y_patches[indexes_for_train]

# Validation set
x_valid = x_patches[indexes_for_valid]
y_valid = y_patches[indexes_for_valid]

print( "Número de imagens no conjunto de treinamento: %d " % ( len(x_train) ) )
print( "Número de imagens no conjunto de validação: %d " % ( len(x_valid) ) )

# Freeing up memory
x_patches = 0
y_patches = 0

####################### Fazendo o mesmo treinamento para a train2
#valid_percent = 0.2
#limit = len(x_patches2) - int (len(x_patches2)*valid_percent )

#indexes = [i for i in range(x_patches2.shape[0])]

#random.shuffle(indexes)

#indexes_for_train2 = indexes[:limit]

#indexes_for_valid2 = indexes[limit:]

#x_train2 = x_patches2[indexes_for_train2]
#y_train2 = y_patches2[indexes_for_train2]

#x_valid2 = x_patches2[indexes_for_valid2]
#y_valid2 = y_patches2[indexes_for_valid2]

#print( "Número de imagens no conjunto de treinamento: %d " % ( len(x_train2) ) )
#print( "Número de imagens no conjunto de validação: %d " % ( len(x_valid2) ) )

#x_patches2 = 0
#y_patches2 = 0

#################concatenando os patches das img Trains 1 e 2

#x_train = np.concatenate([x_train, x_train2], axis = 0)
#y_train = np.concatenate([y_train, y_train2], axis = 0)
#x_valid = np.concatenate([x_valid, x_valid2], axis = 0)
#y_valid = np.concatenate([y_valid, y_valid2], axis = 0)

#print('x_train concatenado:', x_train.shape)
#print('x_valid concatenado:', x_valid.shape)
#print('y_train concatenado:', y_train.shape)
#print('y_valid concatenado:', y_valid.shape)
# Out:
# Número de imagens no conjunto de treinamento: 94
# Número de imagens no conjunto de validação: 23

# %% [markdown]
# # **7. Data augmentation**

# %%
# Setting data augmentation tranformations and creating data generators

# Only rotations by 90 degrees
def orthogonal_rot(image):
    return np.rot90(image, np.random.choice([-1, 0, 1]))

# Tranformations for image patches
datagen_args_x = dict(
        # rotation_range=90, # rotation
        # width_shift_range=0.15, # horizontal shift
        # height_shift_range=0.15, # vertical shift
        # zoom_range=0.25, # zoom
        preprocessing_function=orthogonal_rot,
        horizontal_flip=True, # horizontal flip
        vertical_flip=True, # vertical flip
        # brightness_range=[0.8,1.2], # brightness
        fill_mode='constant',
        cval=0
)

# Transformations for reference patches
datagen_args_y = dict(
        # rotation_range=90, # rotation
        # width_shift_range=0.15, # horizontal shift
        # height_shift_range=0.15, # vertical shift
        # zoom_range=0.25, # zoom
        preprocessing_function=orthogonal_rot,
        horizontal_flip=True, # horizontal flip
        vertical_flip=True, # vertical flip
        fill_mode='constant',
        cval=0
)

# Its necessary to provide the same seed and kwargs to the flow method (images and references)
seed = 1
x_datagen = ImageDataGenerator(**datagen_args_x)
y_datagen = ImageDataGenerator(**datagen_args_y)

# %%
# Example of Data Augmentation for an arbitrary patch

show_index = 25

x_patch = np.expand_dims( x_train[show_index], 0 )
y_patch = np.expand_dims( y_train[show_index], 0 )

x_iterator = x_datagen.flow(x_patch, seed=seed)
y_iterator = y_datagen.flow(y_patch, seed=seed)

data_iterator = next( zip( x_iterator, y_iterator ) )

nrows = 2
ncols = 5
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(25,12))

# generating transformed images
for j in range(ncols):
    data_iterator = next( zip( x_iterator, y_iterator ) )
    ax[0][j].axis('off')
    ax[0][j].imshow(data_iterator[0][0])
    ax[1][j].axis('off')
    ax[1][j].imshow(data_iterator[1][0,:,:,0], cmap='gray', vmin=0, vmax=num_classes )

# %% [markdown]
# # **8. Building the CNN model**

# %%
#Professor, estava fazendo a U-net com API funcional de forma direta porém achei
#esta versão mais limpa na internet (que é identica ao que eu estava fazendo
#porém organizado em funções). A fonte do código é:
#https://www.youtube.com/watch?v=NKOOA_xxCKE

def conv_bloc(input, f):
  x = Conv2D(f, 3, padding="same")(input)
  #x = BatchNormalization()(x)
  x = Activation("relu")(x)

  x = Conv2D(f, 3, padding="same")(x)
  #x = BatchNormalization()(x)
  x = Activation("relu")(x)
  return x

def encoder(input, f):
  x = conv_bloc(input, f)
  mp = MaxPool2D((2,2))(x)
  return x, mp

def decoder(input, skip, f):
  x = Conv2DTranspose(f, (2,2), strides=2, padding="same")(input)
  x = concatenate([x, skip])
  x = conv_bloc(x, f)
  return x

def unet(input_shape):
  input = Input(input_shape)

  #parte 1 da unet
  bloco1, mp1 = encoder(input, 64)
  bloco2, mp2 = encoder(mp1, 128)
  bloco3, mp3 = encoder(mp2, 256)
  bloco4, mp4 = encoder(mp3, 514)
  #base da unet
  u = conv_bloc(mp4, 1024)
  #parte 2 da unet
  s1 = decoder(u, bloco4, 512)
  s2 = decoder(s1, bloco3, 256)
  s3 = decoder(s2, bloco2, 128)
  s4 = decoder(s3, bloco1, 64)

  output = Conv2D(num_classes, (1,1), padding="same", activation="softmax")(s4)

  model = Model(input, output, name="U-Net")

  return model

# %%
model = unet(input_shape)
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 256, 256, 4  0           []
#                                 )]
#
#  conv2d_95 (Conv2D)             (None, 256, 256, 64  2368        ['input_6[0][0]']
#                                 )
#
#  activation_90 (Activation)     (None, 256, 256, 64  0           ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 256, 256, 64  36928       ['activation_90[0][0]']
#                                 )
#
#  activation_91 (Activation)     (None, 256, 256, 64  0           ['conv2d_96[0][0]']
#                                 )
#
#  max_pooling2d_20 (MaxPooling2D  (None, 128, 128, 64  0          ['activation_91[0][0]']
#  )                              )
#
#  conv2d_97 (Conv2D)             (None, 128, 128, 12  73856       ['max_pooling2d_20[0][0]']
#                                 8)
#
#  activation_92 (Activation)     (None, 128, 128, 12  0           ['conv2d_97[0][0]']
#                                 8)
#
#  conv2d_98 (Conv2D)             (None, 128, 128, 12  147584      ['activation_92[0][0]']
#                                 8)
#
#  activation_93 (Activation)     (None, 128, 128, 12  0           ['conv2d_98[0][0]']
#                                 8)
#
#  max_pooling2d_21 (MaxPooling2D  (None, 64, 64, 128)  0          ['activation_93[0][0]']
#  )
#
#  conv2d_99 (Conv2D)             (None, 64, 64, 256)  295168      ['max_pooling2d_21[0][0]']
#
#  activation_94 (Activation)     (None, 64, 64, 256)  0           ['conv2d_99[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 64, 64, 256)  590080      ['activation_94[0][0]']
#
#  activation_95 (Activation)     (None, 64, 64, 256)  0           ['conv2d_100[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 32, 32, 256)  0          ['activation_95[0][0]']
#  )
#
#  conv2d_101 (Conv2D)            (None, 32, 32, 514)  1184770     ['max_pooling2d_22[0][0]']
#
#  activation_96 (Activation)     (None, 32, 32, 514)  0           ['conv2d_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 32, 32, 514)  2378278     ['activation_96[0][0]']
#
#  activation_97 (Activation)     (None, 32, 32, 514)  0           ['conv2d_102[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 16, 16, 514)  0          ['activation_97[0][0]']
#  )
#
#  conv2d_103 (Conv2D)            (None, 16, 16, 1024  4738048     ['max_pooling2d_23[0][0]']
#                                 )
#
#  activation_98 (Activation)     (None, 16, 16, 1024  0           ['conv2d_103[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 16, 16, 1024  9438208     ['activation_98[0][0]']
#                                 )
#
#  activation_99 (Activation)     (None, 16, 16, 1024  0           ['conv2d_104[0][0]']
#                                 )
#
#  conv2d_transpose_20 (Conv2DTra  (None, 32, 32, 512)  2097664    ['activation_99[0][0]']
#  nspose)
#
#  concatenate_20 (Concatenate)   (None, 32, 32, 1026  0           ['conv2d_transpose_20[0][0]',
#                                 )                                 'activation_97[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 32, 32, 512)  4728320     ['concatenate_20[0][0]']
#
#  activation_100 (Activation)    (None, 32, 32, 512)  0           ['conv2d_105[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 32, 32, 512)  2359808     ['activation_100[0][0]']
#
#  activation_101 (Activation)    (None, 32, 32, 512)  0           ['conv2d_106[0][0]']
#
#  conv2d_transpose_21 (Conv2DTra  (None, 64, 64, 256)  524544     ['activation_101[0][0]']
#  nspose)
#
#  concatenate_21 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_transpose_21[0][0]',
#                                                                   'activation_95[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 64, 64, 256)  1179904     ['concatenate_21[0][0]']
#
#  activation_102 (Activation)    (None, 64, 64, 256)  0           ['conv2d_107[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 64, 64, 256)  590080      ['activation_102[0][0]']
#
#  activation_103 (Activation)    (None, 64, 64, 256)  0           ['conv2d_108[0][0]']
#
#  conv2d_transpose_22 (Conv2DTra  (None, 128, 128, 12  131200     ['activation_103[0][0]']
#  nspose)                        8)
#
#  concatenate_22 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_transpose_22[0][0]',
#                                 6)                                'activation_93[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 128, 128, 12  295040      ['concatenate_22[0][0]']
#                                 8)
#
#  activation_104 (Activation)    (None, 128, 128, 12  0           ['conv2d_109[0][0]']
#                                 8)
#
#  conv2d_110 (Conv2D)            (None, 128, 128, 12  147584      ['activation_104[0][0]']
#                                 8)
#
#  activation_105 (Activation)    (None, 128, 128, 12  0           ['conv2d_110[0][0]']
#                                 8)
#
#  conv2d_transpose_23 (Conv2DTra  (None, 256, 256, 64  32832      ['activation_105[0][0]']
#  nspose)                        )
#
#  concatenate_23 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_transpose_23[0][0]',
#                                 8)                                'activation_91[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 256, 256, 64  73792       ['concatenate_23[0][0]']
#                                 )
#
#  activation_106 (Activation)    (None, 256, 256, 64  0           ['conv2d_111[0][0]']
#                                 )
#
#  conv2d_112 (Conv2D)            (None, 256, 256, 64  36928       ['activation_106[0][0]']
#                                 )
#
#  activation_107 (Activation)    (None, 256, 256, 64  0           ['conv2d_112[0][0]']
#                                 )
#
#  conv2d_113 (Conv2D)            (None, 256, 256, 6)  390         ['activation_107[0][0]']
#
# ==================================================================================================
# Total params: 31,083,374
# Trainable params: 31,083,374
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # **9. Functions for training the network**

# %%
# Functions for training

def set_number_of_batches(qt_train_samples, qt_valid_samples, batch_size, data_augmentation, number_samples_for_generator=6):
    if data_augmentation:
        train_batchs_qtd = qt_train_samples//number_samples_for_generator
        valid_batchs_qtd = qt_valid_samples//number_samples_for_generator
    else:
        train_batchs_qtd = qt_train_samples//batch_size
        valid_batchs_qtd = qt_valid_samples//batch_size

    return train_batchs_qtd, valid_batchs_qtd

def get_batch_samples(x, y, batch, batch_size, data_augmentation, number_samples_for_generator):
    if data_augmentation:
        x_batch = x[batch * number_samples_for_generator : (batch + 1) * number_samples_for_generator, : , : , :]
        y_batch = y[batch * number_samples_for_generator : (batch + 1) * number_samples_for_generator, : , : , :]

        x_iterator = x_datagen.flow(x_batch, seed=batch)
        y_iterator = y_datagen.flow(y_batch, seed=batch)

        x_batch = np.array([next(x_iterator)[0] for _ in range(batch_size)])
        y_batch = np.array([next(y_iterator)[0] for _ in range(batch_size)])
    else:
        x_batch = x[batch * batch_size : (batch + 1) * batch_size, : , : , :]
        y_batch = y[batch * batch_size : (batch + 1) * batch_size, : , : , :]

    return x_batch, y_batch

def train_unet(net, x_train, y_train, x_valid, y_valid, batch_size, epochs, early_stopping_epochs, early_stopping_delta, filepath, filename, data_augmentation=False, number_samples_for_generator=1):
    print('Start the training...')

    # calculating number of batches
    train_batchs_qtd, valid_batchs_qtd = set_number_of_batches(x_train.shape[0], x_valid.shape[0], batch_size, data_augmentation, number_samples_for_generator)

    history_train = []
    history_valid = []
    valid_loss_best_model = float('inf')
    no_improvement_count = 0

    for epoch in range(epochs):
        print('Start epoch ... %d ' %(epoch) )
        # shuffle train set
        x_train, y_train = shuffle(x_train , y_train, random_state = 0)

        # TRAINING
        train_loss = np.zeros((1 , 2))
        # mini batches strategy
        for  batch in range(train_batchs_qtd):
            print('Start batch ... %d ' %(batch) )
            x_train_batch, y_train_batch = get_batch_samples(x_train, y_train, batch, batch_size, data_augmentation, number_samples_for_generator)
            train_loss = train_loss + net.train_on_batch(x_train_batch, y_train_batch)

        # Estimating the loss in the training set
        train_loss = train_loss/train_batchs_qtd

        # VALIDATING
        valid_loss = np.zeros((1 , 2))
        # Evaluating the network (model) with the validation set
        for  batch in range(valid_batchs_qtd):
            x_valid_batch, y_valid_batch = get_batch_samples(x_valid, y_valid, batch, batch_size, data_augmentation, number_samples_for_generator)
            valid_loss = valid_loss + net.test_on_batch(x_valid_batch, y_valid_batch)

        # Estimating the loss in the validation set
        valid_loss = valid_loss/valid_batchs_qtd

        # Showing the results.
        print("%d [training loss: %f , Train acc.: %.2f%%][Test loss: %f , Test acc.:%.2f%%]" %(epoch , train_loss[0 , 0], 100*train_loss[0 , 1] , valid_loss[0 , 0] , 100 * valid_loss[0 , 1]))
        history_train.append( train_loss )
        history_valid.append( valid_loss )

        # Early Stopping
        if (1-(valid_loss[0 , 0]/valid_loss_best_model)) < early_stopping_delta:
            if no_improvement_count+1 >= early_stopping_epochs:
                print('Early Stopping reached')
                break
            else:
                no_improvement_count = no_improvement_count+1
        else:
            valid_loss_best_model = valid_loss[0 , 0]
            no_improvement_count = 0

            # Saving best model
            print("Saving the model...")
            net.save(filepath+filename+'.h5')

    return [ history_train, history_valid ]

# %% [markdown]
# # **10. Defining hyperparameters**

# %%
# Defining hyperparameters for training

batch_size = 16
epochs = 150

# Fixed class weights: [Impervious surfaces, Low vegetation, Building, Tree, Car]
#class_weights = [0.1, 0.1, 0.1 , 0.1, 2.0]


class_weights = [0.10, 0.05, 0.10 , 0.05, 4.00]
#class_weights = [0.7, 0.3, 0.7 , 0.5, 9.00]

# Early stoping parameters
#early_stopping_epochs = 10
early_stopping_epochs = 20
early_stopping_delta = 0.00001 # delta improvement equivalent to 0.01%

data_augmentation = True
number_samples_for_generator = 4

# optimizer
#adam = Adam(learning_rate = 0.0001 , beta_1=0.9)
adam = Adam(learning_rate = 0.0001 , beta_1=0.9)

# %% [markdown]
# # **11. Start training**

# %%
# Compile the model
model.compile(loss = "sparse_categorical_crossentropy", optimizer=adam , metrics=['accuracy'], loss_weights=class_weights)

# Train the model
best_model_filename = 'best_CNN_model'
#history = train_unet(model, x_train, y_train, x_valid, y_valid, batch_size, epochs, early_stopping_epochs, early_stopping_delta, root_path, best_model_filename, data_augmentation, number_samples_for_generator)
#Uncomment the line above for training with the whole dataset!!!
history = train_unet(model, x_train[0:64], y_train[0:64], x_valid[0:16], y_valid[0:16], batch_size, epochs, early_stopping_epochs, early_stopping_delta, root_path, best_model_filename, data_augmentation, number_samples_for_generator)
# Out:
# Start the training...
# Start epoch ... 0
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 0 [training loss: 0.194774 , Train acc.: 39.59%][Test loss: 0.137854 , Test acc.:32.66%]
# Saving the model...
# Start epoch ... 1
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 1 [training loss: 0.100548 , Train acc.: 58.58%][Test loss: 0.108521 , Test acc.:44.60%]
# Saving the model...
# Start epoch ... 2
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 2 [training loss: 0.090360 , Train acc.: 61.71%][Test loss: 0.097224 , Test acc.:58.79%]
# Saving the model...
# Start epoch ... 3
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 3 [training loss: 0.083051 , Train acc.: 65.93%][Test loss: 0.097513 , Test acc.:57.57%]
# Start epoch ... 4
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 4 [training loss: 0.087772 , Train acc.: 62.34%][Test loss: 0.087724 , Test acc.:66.77%]
# Saving the model...
# Start epoch ... 5
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 5 [training loss: 0.079470 , Train acc.: 68.54%][Test loss: 0.083709 , Test acc.:64.59%]
# Saving the model...
# Start epoch ... 6
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 6 [training loss: 0.074564 , Train acc.: 69.91%][Test loss: 0.081296 , Test acc.:66.42%]
# Saving the model...
# Start epoch ... 7
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 7 [training loss: 0.077805 , Train acc.: 67.48%][Test loss: 0.104552 , Test acc.:58.17%]
# Start epoch ... 8
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 8 [training loss: 0.080291 , Train acc.: 67.50%][Test loss: 0.084905 , Test acc.:66.58%]
# Start epoch ... 9
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 9 [training loss: 0.075428 , Train acc.: 70.64%][Test loss: 0.077866 , Test acc.:69.58%]
# Saving the model...
# Start epoch ... 10
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 10 [training loss: 0.070107 , Train acc.: 72.24%][Test loss: 0.082732 , Test acc.:67.59%]
# Start epoch ... 11
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 11 [training loss: 0.069961 , Train acc.: 72.44%][Test loss: 0.074915 , Test acc.:72.48%]
# Saving the model...
# Start epoch ... 12
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 12 [training loss: 0.069762 , Train acc.: 73.15%][Test loss: 0.075752 , Test acc.:71.11%]
# Start epoch ... 13
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 13 [training loss: 0.071747 , Train acc.: 72.33%][Test loss: 0.073882 , Test acc.:73.23%]
# Saving the model...
# Start epoch ... 14
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 14 [training loss: 0.069775 , Train acc.: 72.23%][Test loss: 0.070873 , Test acc.:73.74%]
# Saving the model...
# Start epoch ... 15
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 15 [training loss: 0.071817 , Train acc.: 72.61%][Test loss: 0.072678 , Test acc.:73.03%]
# Start epoch ... 16
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 16 [training loss: 0.067291 , Train acc.: 74.61%][Test loss: 0.079484 , Test acc.:68.16%]
# Start epoch ... 17
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 17 [training loss: 0.068078 , Train acc.: 73.63%][Test loss: 0.070432 , Test acc.:72.36%]
# Saving the model...
# Start epoch ... 18
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 18 [training loss: 0.062700 , Train acc.: 76.06%][Test loss: 0.072697 , Test acc.:72.92%]
# Start epoch ... 19
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 19 [training loss: 0.062481 , Train acc.: 76.22%][Test loss: 0.067821 , Test acc.:74.11%]
# Saving the model...
# Start epoch ... 20
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 20 [training loss: 0.065338 , Train acc.: 75.30%][Test loss: 0.070647 , Test acc.:72.33%]
# Start epoch ... 21
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 21 [training loss: 0.067320 , Train acc.: 73.70%][Test loss: 0.065830 , Test acc.:75.36%]
# Saving the model...
# Start epoch ... 22
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 22 [training loss: 0.064217 , Train acc.: 75.36%][Test loss: 0.069138 , Test acc.:72.69%]
# Start epoch ... 23
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 23 [training loss: 0.064751 , Train acc.: 76.13%][Test loss: 0.065213 , Test acc.:74.65%]
# Saving the model...
# Start epoch ... 24
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 24 [training loss: 0.064633 , Train acc.: 74.57%][Test loss: 0.073069 , Test acc.:71.99%]
# Start epoch ... 25
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 25 [training loss: 0.062776 , Train acc.: 75.91%][Test loss: 0.064564 , Test acc.:75.49%]
# Saving the model...
# Start epoch ... 26
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 26 [training loss: 0.068300 , Train acc.: 72.19%][Test loss: 0.078043 , Test acc.:69.84%]
# Start epoch ... 27
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 27 [training loss: 0.067086 , Train acc.: 73.60%][Test loss: 0.066918 , Test acc.:73.88%]
# Start epoch ... 28
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 28 [training loss: 0.066080 , Train acc.: 74.27%][Test loss: 0.077618 , Test acc.:72.00%]
# Start epoch ... 29
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 29 [training loss: 0.065236 , Train acc.: 74.35%][Test loss: 0.081876 , Test acc.:69.39%]
# Start epoch ... 30
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 30 [training loss: 0.064235 , Train acc.: 75.34%][Test loss: 0.072476 , Test acc.:73.65%]
# Start epoch ... 31
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 31 [training loss: 0.060459 , Train acc.: 76.81%][Test loss: 0.068464 , Test acc.:73.06%]
# Start epoch ... 32
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 32 [training loss: 0.060535 , Train acc.: 76.43%][Test loss: 0.062764 , Test acc.:76.07%]
# Saving the model...
# Start epoch ... 33
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 33 [training loss: 0.056431 , Train acc.: 78.51%][Test loss: 0.062062 , Test acc.:76.80%]
# Saving the model...
# Start epoch ... 34
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 34 [training loss: 0.060429 , Train acc.: 76.26%][Test loss: 0.070954 , Test acc.:71.97%]
# Start epoch ... 35
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 35 [training loss: 0.061463 , Train acc.: 76.22%][Test loss: 0.070259 , Test acc.:73.78%]
# Start epoch ... 36
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 36 [training loss: 0.064239 , Train acc.: 74.83%][Test loss: 0.066024 , Test acc.:75.07%]
# Start epoch ... 37
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 37 [training loss: 0.062507 , Train acc.: 75.90%][Test loss: 0.063808 , Test acc.:76.01%]
# Start epoch ... 38
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 38 [training loss: 0.059096 , Train acc.: 77.34%][Test loss: 0.065533 , Test acc.:75.52%]
# Start epoch ... 39
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 39 [training loss: 0.057418 , Train acc.: 77.59%][Test loss: 0.063612 , Test acc.:75.12%]
# Start epoch ... 40
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 40 [training loss: 0.058070 , Train acc.: 77.06%][Test loss: 0.075427 , Test acc.:71.77%]
# Start epoch ... 41
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 41 [training loss: 0.061509 , Train acc.: 76.00%][Test loss: 0.082300 , Test acc.:68.47%]
# Start epoch ... 42
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 42 [training loss: 0.064592 , Train acc.: 74.92%][Test loss: 0.068246 , Test acc.:73.85%]
# Start epoch ... 43
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 43 [training loss: 0.060893 , Train acc.: 76.13%][Test loss: 0.067512 , Test acc.:72.33%]
# Start epoch ... 44
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 44 [training loss: 0.058937 , Train acc.: 76.44%][Test loss: 0.081068 , Test acc.:71.55%]
# Start epoch ... 45
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 45 [training loss: 0.054008 , Train acc.: 79.08%][Test loss: 0.069155 , Test acc.:73.89%]
# Start epoch ... 46
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 46 [training loss: 0.053585 , Train acc.: 79.13%][Test loss: 0.061814 , Test acc.:76.55%]
# Saving the model...
# Start epoch ... 47
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 47 [training loss: 0.054775 , Train acc.: 78.95%][Test loss: 0.060383 , Test acc.:76.78%]
# Saving the model...
# Start epoch ... 48
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 48 [training loss: 0.057704 , Train acc.: 77.19%][Test loss: 0.065757 , Test acc.:74.73%]
# Start epoch ... 49
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 49 [training loss: 0.054182 , Train acc.: 79.36%][Test loss: 0.065569 , Test acc.:74.30%]
# Start epoch ... 50
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 50 [training loss: 0.054288 , Train acc.: 78.21%][Test loss: 0.060402 , Test acc.:77.17%]
# Start epoch ... 51
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 51 [training loss: 0.057250 , Train acc.: 76.82%][Test loss: 0.064940 , Test acc.:76.01%]
# Start epoch ... 52
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 52 [training loss: 0.051458 , Train acc.: 79.93%][Test loss: 0.074454 , Test acc.:71.96%]
# Start epoch ... 53
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 53 [training loss: 0.053554 , Train acc.: 79.59%][Test loss: 0.065784 , Test acc.:74.87%]
# Start epoch ... 54
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 54 [training loss: 0.060587 , Train acc.: 76.07%][Test loss: 0.071189 , Test acc.:70.94%]
# Start epoch ... 55
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 55 [training loss: 0.062578 , Train acc.: 74.44%][Test loss: 0.066456 , Test acc.:74.75%]
# Start epoch ... 56
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 56 [training loss: 0.056941 , Train acc.: 77.87%][Test loss: 0.071486 , Test acc.:72.39%]
# Start epoch ... 57
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 57 [training loss: 0.056638 , Train acc.: 77.56%][Test loss: 0.065373 , Test acc.:74.77%]
# Start epoch ... 58
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 58 [training loss: 0.054047 , Train acc.: 78.85%][Test loss: 0.067529 , Test acc.:75.37%]
# Start epoch ... 59
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 59 [training loss: 0.067488 , Train acc.: 72.83%][Test loss: 0.078473 , Test acc.:66.69%]
# Start epoch ... 60
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 60 [training loss: 0.061971 , Train acc.: 75.48%][Test loss: 0.067215 , Test acc.:74.82%]
# Start epoch ... 61
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 61 [training loss: 0.057547 , Train acc.: 77.98%][Test loss: 0.061663 , Test acc.:76.63%]
# Start epoch ... 62
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 62 [training loss: 0.053833 , Train acc.: 78.58%][Test loss: 0.062118 , Test acc.:76.58%]
# Start epoch ... 63
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 63 [training loss: 0.055968 , Train acc.: 78.11%][Test loss: 0.075647 , Test acc.:70.82%]
# Start epoch ... 64
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 64 [training loss: 0.053645 , Train acc.: 78.80%][Test loss: 0.061555 , Test acc.:76.19%]
# Start epoch ... 65
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 65 [training loss: 0.051003 , Train acc.: 79.89%][Test loss: 0.061066 , Test acc.:75.61%]
# Start epoch ... 66
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 66 [training loss: 0.050903 , Train acc.: 80.05%][Test loss: 0.064183 , Test acc.:74.66%]
# Start epoch ... 67
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Start batch ... 8
# Start batch ... 9
# Start batch ... 10
# Start batch ... 11
# Start batch ... 12
# Start batch ... 13
# Start batch ... 14
# Start batch ... 15
# 67 [training loss: 0.052816 , Train acc.: 79.17%][Test loss: 0.068660 , Test acc.:74.91%]
# Early Stopping reached

# %% [markdown]
# # **12. Training History Graph**

# %%
# Functions

def show_graph_loss_accuracy(history,accuracy_position):
    plt.rcParams['axes.facecolor']='white'
    plt.figure(num=1, figsize=(14,6))

    config = [ { 'title': 'model accuracy', 'ylabel': 'accuracy', 'legend_position': 'upper left', 'index_position': accuracy_position },
               { 'title': 'model loss', 'ylabel': 'loss', 'legend_position': 'upper right', 'index_position': 0 } ]

    for i in range(len(config)):

        plot_number = 120 + (i+1)
        plt.subplot(plot_number)
        plt.plot(history[0,:,0,config[i]['index_position']])
        plt.plot(history[1,:,0,config[i]['index_position']])
        plt.title(config[i]['title'])
        plt.ylabel(config[i]['ylabel'])
        plt.xlabel('epoch')
        plt.legend(['train', 'valid'], loc=config[i]['legend_position'])
        plt.tight_layout()

    plt.show()

# %%
# Show history

show_graph_loss_accuracy(np.asarray(history),1)

# %% [markdown]
# # **13. Evaluating the CNN model over training and validation data**

# %%
# Functions

def Test(model, patch_test):
    result = model.predict(patch_test)
    predicted_classes = np.argmax(result, axis=-1)
    return predicted_classes

def compute_metrics(true_labels, predicted_labels):
    accuracy = 100*accuracy_score(true_labels, predicted_labels)
    f1score = 100*f1_score(true_labels, predicted_labels, average=None)
    recall = 100*recall_score(true_labels, predicted_labels, average=None)
    precision = 100*precision_score(true_labels, predicted_labels, average=None)
    return accuracy, f1score, recall, precision

# %%
# load the best model (.h5 file)
model = load_model(root_path + best_model_filename + '.h5', compile=False)

# Test the model over training and validation data
pred_train = Test(model, x_train)
pred_valid = Test(model, x_valid)

# %%
# Showing the prediction for an arbitrary training patch

index = 20

print('\nPlotting images...')
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, figsize=(15, 15))

ax1.imshow(x_train[index])
ax1.set_title('Patch', fontsize=20)
ax1.axis('off')

ax2.imshow( y_train[index, :, :, 0], cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference', fontsize=20)
ax2.axis('off')

ax3.imshow( pred_train[index], cmap='gray', vmin=0, vmax=num_classes )
ax3.set_title('Prediction', fontsize=20)
ax3.axis('off')
# Out:
# Plotting images...
# (-0.5, 255.5, 255.5, -0.5)

# %%
# Showing the confusion matrix and accuracy metrics for the training data

true_labels = np.reshape(y_train, (y_train.shape[0]* y_train.shape[1]*y_train.shape[2]))
predicted_labels = np.reshape(pred_train, (pred_train.shape[0]* pred_train.shape[1]*pred_train.shape[2]))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
print('Confusion  matrix')
print('=================')
print(cm)

# Metrics
metrics = compute_metrics(true_labels, predicted_labels)
print('\nMetrics')
print('=======')
print('Accuracy: ', metrics[0])
print('F1score: ', metrics[1])
print('Recall: ', metrics[2])
print('Precision: ', metrics[3])
# Out:
# Confusion  matrix
# =================
# [[1089654  181085   39614   67799     109]
#  [  44149 1191614   29467  340881       0]
#  [ 148304   58362  975780   20816      52]
#  [  29541  147866    9071 1771352       0]
#  [   8889     785    4023     295     876]]
#
# Metrics
# =======
# Accuracy:  81.63900172456782
# F1score:  [80.75106029 74.80729469 86.30375245 85.1821832  11.01540396]
# Recall:  [79.06006192 74.192506   81.09105354 90.47527109  5.89184826]
# Precision:  [82.51597646 75.43235729 92.2326564  80.47419    84.47444552]

# %%
# Showing the confusion matrix and accuracy metrics for the validation data

true_labels = np.reshape(y_valid, (y_valid.shape[0]* y_valid.shape[1]*y_valid.shape[2]))
predicted_labels = np.reshape(pred_valid, (pred_valid.shape[0]* pred_valid.shape[1]*pred_valid.shape[2]))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
print('Confusion  matrix')
print('=================')
print(cm)

# Metrics
metrics = compute_metrics(true_labels, predicted_labels)
print('\nMetrics')
print('=======')
print('Accuracy: ', metrics[0])
print('F1score: ', metrics[1])
print('Recall: ', metrics[2])
print('Precision: ', metrics[3])
# Out:
# Confusion  matrix
# =================
# [[333994  44992  21246  17482     54]
#  [ 15445 206099   9468  97387     34]
#  [ 29562  17146 225615   8667      0]
#  [  7290  54179   3035 410845      0]
#  [  2211    190   1734    521    132]]
#
# Metrics
# =======
# Accuracy:  78.0642965565557
# F1score:  [82.84916963 63.31387213 83.23925267 81.33523253  5.2715655 ]
# Recall:  [79.94724345 62.75222039 80.29289299 86.43018077  2.75689223]
# Precision:  [85.969699   63.88566859 86.41008357 76.80752736 60.        ]

# %%
# Freeing up memory

x_train = 0
y_train = 0
x_valid = 0
y_valid = 0
pred_train = 0
pred_valid = 0
true_labels = 0
predicted_labels = 0

# %% [markdown]
# # **14. Inference (testing the CNN model)**

# %%
# load the best model (.h5 file)
best_model_filename = 'best_CNN_model'
model = load_model(root_path + best_model_filename + '.h5', compile=False)

# %%
# Constants

# patch_size defines the measures (spatial dimensions) of the patch.
# Working with square patches (H = W). Therefore, a scalar variable is enough.
patch_test_size = patch_size
patch_test_stride = 128

# %%
# Extracting test patches

#x_patches_test, y_patches_test = extract_patches(image_test, labels_test, patch_test_size, patch_test_stride, True)

#descomente a linha abaixo para usar a imagem de tes com dsm
x_patches_test, y_patches_test = extract_patches(test_dsm, labels_test, patch_test_size, patch_test_stride, True)

print( "Number of patches: %d %s " % ( x_patches_test.shape[0], x_patches_test.shape[1:] ) )
print( "Number of labeled references: %d %s " % ( y_patches_test.shape[0], y_patches_test.shape[1:] ) )
# Out:
# Image dimensions: (2558, 2818, 4)
# Reference dimensions: (2558, 2818)
# Number of patches: 418 (256, 256, 4)
# Number of labeled references: 418 (256, 256)

# %% [markdown]
# # **15. Prediction over test patches**

# %%
# Test the model over test patches

pred_test_patches = Test(model, x_patches_test)
print(pred_test_patches.shape)
# Out:
# (418, 256, 256)

# %%
# Showing prediction result for an arbitrary test patch

index = 20

print('\nPlotting images...')
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, figsize=(15, 15))

ax1.imshow(x_patches_test[index])
ax1.set_title('Patch', fontsize=20)
ax1.axis('off')

ax2.imshow( y_patches_test[index], cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference', fontsize=20)
ax2.axis('off')

ax3.imshow( pred_test_patches[index], cmap='gray', vmin=0, vmax=num_classes )
ax3.set_title('Prediction', fontsize=20)
ax3.axis('off')
# Out:
# Plotting images...
# (-0.5, 255.5, 255.5, -0.5)

# %%
# Showing the confusion matrix and accuracy metrics for the test data (patches)

true_labels = np.reshape(y_patches_test, (y_patches_test.shape[0]* y_patches_test.shape[1]*y_patches_test.shape[2]))
predicted_labels = np.reshape(pred_test_patches, (pred_test_patches.shape[0]* pred_test_patches.shape[1]*pred_test_patches.shape[2]))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
print('Confusion  matrix')
print('=================')
print(cm)

# Metrics
metrics = compute_metrics(true_labels, predicted_labels)
print('\nMetrics')
print('=======')
print('Accuracy: ', metrics[0])
print('F1score: ', metrics[1])
print('Recall: ', metrics[2])
print('Precision: ', metrics[3])
# Out:
# Confusion  matrix
# =================
# [[1311810  588786 2323414  771973     785]
#  [ 565954 2906053 1091221 4907418      22]
#  [ 375851  131187 4266997   97775     491]
#  [  74887  299300   54160 7521156       0]
#  [  13447    7040   81349    2713     259]]
#
# Metrics
# =======
# Accuracy:  58.42975452185818
# F1score:  [35.7503907  43.36410696 67.25271292 70.78555846  0.4870023 ]
# Recall:  [26.25317005 30.68477324 87.5766296  94.61165056  0.24711854]
# Precision:  [56.01360235 73.900878   54.58513541 56.54564476 16.63455363]

# %% [markdown]
# # **16. Mosaic of the test patches predictions**

# %%
# Assembling mosaic of the test patches predictions

pred_test_mosaic = np.zeros(labels_test.shape)
patch_test_overlap = patch_test_stride/patch_test_size

# Image positions
x = y = 0
xmax, ymax = labels_test.shape

# Patch positions
pi = patch_test_size//2 - int(patch_test_size*patch_test_overlap**2)
pf = patch_test_size//2 + int(patch_test_size*patch_test_overlap**2)

for patch in pred_test_patches:
  if y==0: ypi = 0
  else: ypi = pi
  if y+pf+patch_test_stride>ymax: ypf = ymax-y-2
  else: ypf = pf
  if x==0: xpi = 0
  else: xpi = pi
  if x+pf+patch_test_stride>xmax: xpf = xmax-x
  else: xpf = pf

  pred_test_mosaic[x+xpi:x+xpf,y+ypi:y+ypf] = patch[xpi:xpf,ypi:ypf]

  y += patch_test_stride
  if y+patch_test_stride >= ymax:
    x += patch_test_stride
    y = 0

# %%
# Showing prediction results mosaic

print('\nPlotting images...')
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, figsize=(15, 15))

ax1.imshow( image_test )
ax1.set_title('Image', fontsize=20)
ax1.axis('off')

ax2.imshow( labels_test, cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference', fontsize=20)
ax2.axis('off')

ax3.imshow( pred_test_mosaic, cmap='gray', vmin=0, vmax=num_classes )
ax3.set_title('Prediction', fontsize=20)
ax3.axis('off')
# Out:
# Plotting images...
# (-0.5, 2817.5, 2557.5, -0.5)

# %%
# Showing the confusion matrix and accuracy metrics for the prediction results mosaic

true_labels = np.reshape(labels_test, (labels_test.shape[0]*labels_test.shape[1]))
predicted_labels = np.reshape(pred_test_mosaic, (pred_test_mosaic.shape[0]*pred_test_mosaic.shape[1]))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
print('Confusion  matrix')
print('=================')
print(cm)

# Metrics
metrics = compute_metrics(true_labels, predicted_labels)
print('\nMetrics')
print('=======')
print('Accuracy: ', metrics[0])
print('F1score: ', metrics[1])
print('Recall: ', metrics[2])
print('Precision: ', metrics[3])
# Out:
# Confusion  matrix
# =================
# [[ 560764  154989  387267   80713    1491]
#  [ 104619 1155458  214618 1074319      90]
#  [  69477   58491 1126488   47670     642]
#  [  33601  202502   16972 1891142      89]
#  [   6650    5653    5583    1171    7985]]
#
# Metrics
# =======
# Accuracy:  65.78169990638757
# F1score:  [57.21103791 56.00595415 73.77866035 72.1903468  42.77029379]
# Recall:  [47.312913   45.32800545 86.46881102 88.19366266 29.52814141]
# Precision:  [72.34628331 73.26505159 64.33662606 61.10283795 77.54685831]
